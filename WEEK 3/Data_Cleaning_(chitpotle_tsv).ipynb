# %% [markdown]
# SRIJA BASAK
#
# PREPINSTA DATA ANALYTICS INTERNSHIP WEEK 3 TASK 2

# %%
#importing the libraries
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('/content/chipotle.tsv',sep='\t')

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df.size
# Out:
# 23110

# %%
df.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
df.iloc[:,2:4].value_counts()
# Out:
# item_name          choice_description
# Canned Soft Drink  [Coke]                                                                                             102
#                    [Diet Coke]                                                                                         95
#                    [Sprite]                                                                                            55
#                    [Lemonade]                                                                                          31
# Canned Soda        [Coca Cola]                                                                                         26
#                                                                                                                      ...
# Chicken Burrito    [Fresh Tomato Salsa, [Cheese, Sour Cream]]                                                           1
# ...

# %% [markdown]
# The above line of code returns the a series with count of unique values from item_name and choice_description columns combined

# %%
#count of unique values in item_name column
df.item_name.value_counts()
# Out:
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chips and Guacamole                      479
# Steak Burrito                            368
# Canned Soft Drink                        301
# Steak Bowl                               211
# Chips                                    211
# Bottled Water                            162
# Chicken Soft Tacos                       115
# Chips and Fresh Tomato Salsa             110
# Chicken Salad Bowl                       110
# Canned Soda                              104
# Side of Chips                            101
# Veggie Burrito                            95
# Barbacoa Burrito                          91
# Veggie Bowl                               85
# Carnitas Bowl                             68
# Barbacoa Bowl                             66
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# 6 Pack Soft Drink                         54
# ...

# %%
#count of unique values in choice_description column
df.choice_description.value_counts()
# Out:
# [Diet Coke]                                                                                                                                      134
# [Coke]                                                                                                                                           123
# [Sprite]                                                                                                                                          77
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Lettuce]]                                                                            42
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]                                                                 40
#                                                                                                                                                 ...
# ...

# %%
data=df.copy()

# %%
data.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
#Pandas groupby function implementation on item_name column
item_choice=data.groupby(['item_name'])
item_choice.first()
# Out:
#                                        order_id  quantity  \
# item_name
# 6 Pack Soft Drink                           129         1
# Barbacoa Bowl                                19         1
# Barbacoa Burrito                             11         1
# Barbacoa Crispy Tacos                        75         1
# Barbacoa Salad Bowl                         501         1
# Barbacoa Soft Tacos                          26         1
# Bottled Water                                17         1
# Bowl                                        193         3
# Burrito                                     214         1
# Canned Soda                                   9         2
# Canned Soft Drink                           114         1
# Carnitas Bowl                                17         1
# Carnitas Burrito                             14         1
# Carnitas Crispy Tacos                       230         1
# Carnitas Salad                             1500         1
# ...

# %%
#Removing the brackets from the choice_description column using regex
data.choice_description=data.choice_description.str.replace('\[|\]'," ",regex=True)

# %%
#removing extra spaces from the item_name column
data.item_name=data.item_name.str.strip()

# %%
data.choice_description
# Out:
# 0                                                     NaN
# 1                                             Clementine
# 2                                                  Apple
# 3                                                     NaN
# 4        Tomatillo-Red Chili Salsa (Hot),  Black Beans...
#                               ...
# 4617     Fresh Tomato Salsa,  Rice, Black Beans, Sour ...
# 4618     Fresh Tomato Salsa,  Rice, Sour Cream, Cheese...
# 4619     Fresh Tomato Salsa,  Fajita Vegetables, Pinto...
# 4620     Fresh Tomato Salsa,  Fajita Vegetables, Lettu...
# 4621     Fresh Tomato Salsa,  Fajita Vegetables, Pinto...
# Name: choice_description, Length: 4622, dtype: object

# %%
data.choice_description=data.choice_description.fillna("No Description Available")

# %%
data.item_name.value_counts()
# Out:
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chips and Guacamole                      479
# Steak Burrito                            368
# Canned Soft Drink                        301
# Steak Bowl                               211
# Chips                                    211
# Bottled Water                            162
# Chicken Soft Tacos                       115
# Chips and Fresh Tomato Salsa             110
# Chicken Salad Bowl                       110
# Canned Soda                              104
# Side of Chips                            101
# Veggie Burrito                            95
# Barbacoa Burrito                          91
# Veggie Bowl                               85
# Carnitas Bowl                             68
# Barbacoa Bowl                             66
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# 6 Pack Soft Drink                         54
# ...

# %%
data.item_name.value_counts().sum()
# Out:
# 4622

# %%
len(pd.unique(data.item_name))
# Out:
# 50

# %%
data.item_price=data.item_price.str.replace("$","",regex=True)

# %%
data_no_duplicate=data.drop_duplicates(keep='last')

# %%
data_no_duplicate.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                           No Description Available      2.39
# 1                                        Clementine       3.39
# 2                                             Apple       3.39
# 3                           No Description Available      2.39
# 4   Tomatillo-Red Chili Salsa (Hot),  Black Beans...     16.98

# %%
data.shape
# Out:
# (4622, 5)

# %%
data_no_duplicate.shape
# Out:
# (4563, 5)

# %%
data.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                           No Description Available      2.39
# 1                                        Clementine       3.39
# 2                                             Apple       3.39
# 3                           No Description Available      2.39
# 4   Tomatillo-Red Chili Salsa (Hot),  Black Beans...     16.98

# %%
data_group=data_no_duplicate.groupby(['item_name','choice_description'])
data_options=data_group.first() #data type=object

data_options=pd.DataFrame(data_options) #object data type converted to Pandas DataFrame

# %%
data_options
# Out:
#                                                                       order_id  \
# item_name         choice_description
# 6 Pack Soft Drink  Coke                                                    154
#                    Diet Coke                                               148
#                    Lemonade                                               1253
#                    Nestea                                                  298
#                    Sprite                                                  129
# ...                                                                        ...
# Veggie Soft Tacos  Fresh Tomato Salsa,  Black Beans, Cheese, Sour...       322
#                    Fresh Tomato Salsa,  Fajita Vegetables, Rice, ...       688
#                    Roasted Chili Corn Salsa (Medium),  Black Bean...      1132
#                    Roasted Chili Corn Salsa,  Fajita Vegetables, ...       948
# ...

# %%
len(pd.unique(data_no_duplicate.choice_description))
# Out:
# 1044

# %%
data_options.columns
# Out:
# Index(['order_id', 'quantity', 'item_price'], dtype='object')

# %%
data_options.to_csv('cleaned_chitpotle_data.csv')
cleaned_data=pd.read_csv('cleaned_chitpotle_data.csv')

# %%
cleaned_data.head()
# Out:
#            item_name choice_description  order_id  quantity  item_price
# 0  6 Pack Soft Drink              Coke        154         1        6.49
# 1  6 Pack Soft Drink         Diet Coke        148         1        6.49
# 2  6 Pack Soft Drink          Lemonade       1253         1        6.49
# 3  6 Pack Soft Drink            Nestea        298         1        6.49
# 4  6 Pack Soft Drink            Sprite        129         1        6.49

# %%
cleaned_data
# Out:
#               item_name                                 choice_description  \
# 0     6 Pack Soft Drink                                              Coke
# 1     6 Pack Soft Drink                                         Diet Coke
# 2     6 Pack Soft Drink                                          Lemonade
# 3     6 Pack Soft Drink                                            Nestea
# 4     6 Pack Soft Drink                                            Sprite
# ...                 ...                                                ...
# 1866  Veggie Soft Tacos   Fresh Tomato Salsa,  Black Beans, Cheese, Sou...
# 1867  Veggie Soft Tacos   Fresh Tomato Salsa,  Fajita Vegetables, Rice,...
# 1868  Veggie Soft Tacos   Roasted Chili Corn Salsa (Medium),  Black Bea...
# 1869  Veggie Soft Tacos   Roasted Chili Corn Salsa,  Fajita Vegetables,...
# 1870  Veggie Soft Tacos   Tomatillo Red Chili Salsa,  Fajita Vegetables...
#
#       order_id  quantity  item_price
# ...

# %%
cleaned_data.columns
# Out:
# Index(['item_name', 'choice_description', 'order_id', 'quantity',
#        'item_price'],
#       dtype='object')

# %%
len(pd.unique(cleaned_data.item_name))
# Out:
# 50

# %%
cleaned_data.shape
# Out:
# (1871, 5)
