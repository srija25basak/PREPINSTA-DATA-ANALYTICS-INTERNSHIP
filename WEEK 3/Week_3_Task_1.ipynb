# %% [markdown]
# SRIJA BASAK
#
# PREPINSTA DATA ANALYTICS INTERNSHIP WEEK 3 TASK 1

# %%
#importing libraries
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ###Read data

# %%
data=pd.read_csv("/content/Data-cleaning-for-beginners-using-pandas.csv")

# %%
copy_data=data.copy()

# %%
data
# Out:
#     Index   Age      Salary  Rating       Location  Established Easy Apply
# 0       0  44.0   $44k-$99k     5.4       India,In         1999       TRUE
# 1       1  66.0   $55k-$66k     3.5    New York,Ny         2002       TRUE
# 2       2   NaN   $77k-$89k    -1.0    New York,Ny           -1         -1
# 3       3  64.0   $44k-$99k     4.4       India In         1988         -1
# 4       4  25.0   $44k-$99k     6.4  Australia Aus         2002         -1
# 5       5  44.0   $77k-$89k     1.4       India,In         1999       TRUE
# 6       6  21.0   $44k-$99k     0.0    New York,Ny           -1         -1
# 7       7  44.0   $44k-$99k    -1.0  Australia Aus           -1         -1
# 8       8  35.0   $44k-$99k     5.4    New York,Ny           -1         -1
# 9       9  22.0   $44k-$99k     7.7       India,In           -1       TRUE
# 10     10  55.0   $10k-$49k     5.4       India,In         2008       TRUE
# ...

# %%
#Dropping unnecessary columns
data.drop(columns=['Index'],inplace=True)

# %%
#Data types of each indicator
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          22 non-null     float64
#  1   Salary       29 non-null     object
#  2   Rating       28 non-null     float64
#  3   Location     29 non-null     object
#  4   Established  29 non-null     int64
#  5   Easy Apply   29 non-null     object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 1.5+ KB

# %%
data.head()
# Out:
#     Age     Salary  Rating       Location  Established Easy Apply
# 0  44.0  $44k-$99k     5.4       India,In         1999       TRUE
# 1  66.0  $55k-$66k     3.5    New York,Ny         2002       TRUE
# 2   NaN  $77k-$89k    -1.0    New York,Ny           -1         -1
# 3  64.0  $44k-$99k     4.4       India In         1988         -1
# 4  25.0  $44k-$99k     6.4  Australia Aus         2002         -1

# %%
data.tail()
# Out:
#      Age     Salary  Rating       Location  Established Easy Apply
# 24  13.0  $44k-$99k    -1.0    New York,Ny         1987         -1
# 25  55.0  $44k-$99k     0.0  Australia Aus         1980       TRUE
# 26   NaN  $55k-$66k     NaN       India,In         1934       TRUE
# 27  52.0  $44k-$99k     5.4       India,In         1935         -1
# 28   NaN  $39k-$88k     3.4  Australia Aus         1932         -1

# %%
data.shape
# Out:
# (29, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          22 non-null     float64
#  1   Salary       29 non-null     object
#  2   Rating       28 non-null     float64
#  3   Location     29 non-null     object
#  4   Established  29 non-null     int64
#  5   Easy Apply   29 non-null     object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 1.5+ KB

# %%
#finding the count of null values in each column of this dataset
data.isnull().sum()
# Out:
# Age            7
# Salary         0
# Rating         1
# Location       0
# Established    0
# Easy Apply     0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Age', 'Salary', 'Rating', 'Location', 'Established', 'Easy Apply'], dtype='object')

# %%
sample=data.columns.str.lower().str.replace(" ","_")

# %%
text='$40k-$100k'
text.replace('$',"")
# Out:
# '40k-100k'

# %%
sample
# Out:
# Index(['age', 'salary', 'rating', 'location', 'established', 'easy_apply'], dtype='object')

# %% [markdown]
# ###Age column

# %%
#Outlier detection
sns.boxplot(data.Age)
# Out:
# <Axes: ylabel='Age'>

# %% [markdown]
# There are no outliers in the Age column

# %%
avg_age=data['Age'].mean()
avg_age
# Out:
# 39.04545454545455

# %%
sns.displot(data.Age,kind='kde')

# %% [markdown]
# The data is almost normally distributed hence missing values can be replaced by mean

# %%
#filling the missing values with mean
data['Age']=data.Age.fillna(avg_age)
data['Age']=data.Age.round(decimals=1)

# %%
data.head()
# Out:
#     Age     Salary  Rating       Location  Established Easy Apply
# 0  44.0  $44k-$99k     5.4       India,In         1999       TRUE
# 1  66.0  $55k-$66k     3.5    New York,Ny         2002       TRUE
# 2  39.0  $77k-$89k    -1.0    New York,Ny           -1         -1
# 3  64.0  $44k-$99k     4.4       India In         1988         -1
# 4  25.0  $44k-$99k     6.4  Australia Aus         2002         -1

# %%
data.Age.isnull().sum()
# Out:
# 0

# %% [markdown]
# Hence all the null values are replaced in the age column

# %% [markdown]
# ### Location column

# %%
data['Location'].value_counts()
# Out:
# New York,Ny      12
# India,In          9
# Australia Aus     7
# India In          1
# Name: Location, dtype: int64

# %%
data['Location']=data['Location'].replace({'New York,Ny':'New York','India,In':'India','India In':'India','Australia Aus':'Australia'})

# %%
data.Location.head()
# Out:
# 0        India
# 1     New York
# 2     New York
# 3        India
# 4    Australia
# Name: Location, dtype: object

# %%
data.Location.value_counts()
# Out:
# New York     12
# India        10
# Australia     7
# Name: Location, dtype: int64

# %%
#checking for null values
data.Location.isnull().sum()
# Out:
# 0

# %% [markdown]
# Location column contains no null values

# %%
data.columns
# Out:
# Index(['Age', 'Salary', 'Rating', 'Location', 'Established', 'Easy Apply'], dtype='object')

# %% [markdown]
# ### Salary

# %%
#finding existence of null value
data.Salary.isnull().sum()
# Out:
# 0

# %%
data.Salary.value_counts()
# Out:
# $44k-$99k     19
# $55k-$66k      3
# $77k-$89k      2
# $10k-$49k      2
# $88k-$101k     1
# $19k-$40k      1
# $39k-$88k      1
# Name: Salary, dtype: int64

# %% [markdown]
# ###Salary column

# %%
data.Salary.size
# Out:
# 29

# %%
data.Salary=data.Salary.str.replace('$'," ")
# Out:
# <ipython-input-346-416e03525e2d>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data.Salary=data.Salary.str.replace('$'," ")

# %%
data.head()
# Out:
#     Age     Salary  Rating   Location  Established Easy Apply
# 0  44.0   44k- 99k     5.4      India         1999       TRUE
# 1  66.0   55k- 66k     3.5   New York         2002       TRUE
# 2  39.0   77k- 89k    -1.0   New York           -1         -1
# 3  64.0   44k- 99k     4.4      India         1988         -1
# 4  25.0   44k- 99k     6.4  Australia         2002         -1

# %%
data.Salary=data.Salary.str.replace('k','000')

# %%
data.head()
# Out:
#     Age         Salary  Rating   Location  Established Easy Apply
# 0  44.0   44000- 99000     5.4      India         1999       TRUE
# 1  66.0   55000- 66000     3.5   New York         2002       TRUE
# 2  39.0   77000- 89000    -1.0   New York           -1         -1
# 3  64.0   44000- 99000     4.4      India         1988         -1
# 4  25.0   44000- 99000     6.4  Australia         2002         -1

# %%
data.Salary.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 29 entries, 0 to 28
# Series name: Salary
# Non-Null Count  Dtype
# --------------  -----
# 29 non-null     object
# dtypes: object(1)
# memory usage: 360.0+ bytes

# %%
#converting string to integer
data.Salary.value_counts()
# Out:
#  44000- 99000     19
#  55000- 66000      3
#  77000- 89000      2
#  10000- 49000      2
#  88000- 101000     1
#  19000- 40000      1
#  39000- 88000      1
# Name: Salary, dtype: int64

# %%
data.Salary.value_counts()
# Out:
#  44000- 99000     19
#  55000- 66000      3
#  77000- 89000      2
#  10000- 49000      2
#  88000- 101000     1
#  19000- 40000      1
#  39000- 88000      1
# Name: Salary, dtype: int64

# %%
data.columns
# Out:
# Index(['Age', 'Salary', 'Rating', 'Location', 'Established', 'Easy Apply'], dtype='object')

# %%
data.Salary=data.Salary.str.split("- ")

# %%
data.Salary.head()
# Out:
# 0    [ 44000, 99000]
# 1    [ 55000, 66000]
# 2    [ 77000, 89000]
# 3    [ 44000, 99000]
# 4    [ 44000, 99000]
# Name: Salary, dtype: object

# %%
#converting the splitted columns into Starting Salary and Ending Salary respectively
starting=[]
for i in range(data.Salary.size):
  data.Salary.loc[i][0]=int(data.Salary.loc[i][0])
  starting.append(data.Salary.loc[i][0])

# %%
starting
# Out:
# [44000,
#  55000,
#  77000,
#  44000,
#  44000,
#  77000,
#  44000,
#  44000,
#  44000,
#  44000,
#  10000,
#  10000,
#  44000,
#  44000,
#  44000,
#  88000,
#  19000,
#  44000,
#  44000,
#  44000,
#  44000,
#  44000,
#  55000,
#  44000,
#  44000,
#  44000,
#  55000,
#  44000,
#  39000]

# %%
starting=pd.DataFrame(starting)

# %%
starting
# Out:
#         0
# 0   44000
# 1   55000
# 2   77000
# 3   44000
# 4   44000
# 5   77000
# 6   44000
# 7   44000
# 8   44000
# 9   44000
# 10  10000
# 11  10000
# 12  44000
# 13  44000
# 14  44000
# 15  88000
# 16  19000
# 17  44000
# 18  44000
# 19  44000
# 20  44000
# 21  44000
# 22  55000
# 23  44000
# 24  44000
# 25  44000
# 26  55000
# 27  44000
# 28  39000

# %%
data['Starting Salary']=starting

# %%
ending=[]
for i in range(data.Salary.size):
  data.Salary.loc[i][1]=int(data.Salary.loc[i][1])
  ending.append(data.Salary.loc[i][1])

# %%
pd.DataFrame(ending)
# Out:
#          0
# 0    99000
# 1    66000
# 2    89000
# 3    99000
# 4    99000
# 5    89000
# 6    99000
# 7    99000
# 8    99000
# 9    99000
# 10   49000
# 11   49000
# 12   99000
# 13   99000
# 14   99000
# 15  101000
# 16   40000
# 17   99000
# 18   99000
# 19   99000
# 20   99000
# 21   99000
# 22   66000
# 23   99000
# 24   99000
# 25   99000
# 26   66000
# 27   99000
# 28   88000

# %%
data['Maximum Salary']=ending

# %%
data.head()
# Out:
#     Age          Salary   Location Established Easy Apply  Rating Scaled  \
# 0  44.0  [44000, 99000]      India        1999       TRUE       0.727273
# 1  66.0  [55000, 66000]   New York        2002       TRUE       0.511364
# 2  39.0  [77000, 89000]   New York     Unknown      FALSE       0.000000
# 3  64.0  [44000, 99000]      India        1988      FALSE       0.613636
# 4  25.0  [44000, 99000]  Australia        2002      FALSE       0.840909
#
#    Starting Salary  Maximum Salary
# 0            44000           99000
# 1            55000           66000
# 2            77000           89000
# 3            44000           99000
# 4            44000           99000

# %% [markdown]
# Dropping salary column from the dataframe

# %%
data.drop(columns=['Salary'],inplace=True)

# %%
data.head()
# Out:
#     Age   Location Established Easy Apply  Rating Scaled  Starting Salary  \
# 0  44.0      India        1999       TRUE       0.727273            44000
# 1  66.0   New York        2002       TRUE       0.511364            55000
# 2  39.0   New York     Unknown      FALSE       0.000000            77000
# 3  64.0      India        1988      FALSE       0.613636            44000
# 4  25.0  Australia        2002      FALSE       0.840909            44000
#
#    Maximum Salary
# 0           99000
# 1           66000
# 2           89000
# 3           99000
# 4           99000

# %% [markdown]
# ###Rating column

# %%
#Outlier detection
sns.boxplot(data.Rating)
# Out:
# <Axes: ylabel='Rating'>

# %% [markdown]
# The Rating column has no outliers

# %%
#finding null values
data.Rating.isnull().sum()
# Out:
# 1

# %%
data.Rating.value_counts()
# Out:
#  5.4    4
# -1.0    4
#  0.0    3
#  6.7    2
#  4.5    1
#  2.4    1
#  7.8    1
#  5.0    1
#  5.7    1
#  3.3    1
#  5.3    1
#  4.0    1
#  3.0    1
#  3.5    1
#  7.7    1
#  1.4    1
#  6.4    1
#  4.4    1
#  3.4    1
# Name: Rating, dtype: int64

# %%
sns.displot(data.Rating,kind='kde')

# %%
data.Rating.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 29 entries, 0 to 28
# Series name: Rating
# Non-Null Count  Dtype
# --------------  -----
# 28 non-null     float64
# dtypes: float64(1)
# memory usage: 360.0 bytes

# %%
#replacing null values with mean
mean_rating=data.Rating.mean()
data.Rating=data.Rating.fillna(mean_rating)

# %%
data.Rating.isnull().sum()
# Out:
# 0

# %%
data.columns
# Out:
# Index(['Age', 'Salary', 'Rating', 'Location', 'Established', 'Easy Apply'], dtype='object')

# %% [markdown]
# Scaling the rating column using MinMaxScaler

# %%
from sklearn.preprocessing import MinMaxScaler
array=pd.DataFrame(data.Rating)

scaler=MinMaxScaler()
rating_scaled=scaler.fit_transform(array)
rating_scaled=pd.DataFrame(rating_scaled)
rating_scaled.describe()
# Out:
#                0
# count  29.000000
# mean    0.514610
# std     0.315253
# min     0.000000
# 25%     0.272727
# 50%     0.568182
# 75%     0.727273
# max     1.000000

# %%
data['Rating Scaled']=rating_scaled

# %%
data.head()
# Out:
#     Age         Salary  Rating   Location  Established Easy Apply  \
# 0  44.0   44000- 99000     5.4      India         1999       TRUE
# 1  66.0   55000- 66000     3.5   New York         2002       TRUE
# 2  39.0   77000- 89000    -1.0   New York           -1         -1
# 3  64.0   44000- 99000     4.4      India         1988         -1
# 4  25.0   44000- 99000     6.4  Australia         2002         -1
#
#    Rating Scaled
# 0       0.727273
# 1       0.511364
# 2       0.000000
# 3       0.613636
# 4       0.840909

# %% [markdown]
# Dropping the rating column since a scaled rating column has been added

# %%
data.drop(columns=['Rating'],inplace=True)

# %% [markdown]
# ###Established

# %%
data.Established.isnull().sum()
# Out:
# 0

# %%
data.Established.value_counts()
# Out:
#  1999    5
# -1       5
#  1988    2
#  2002    2
#  1955    1
#  1935    1
#  1934    1
#  1980    1
#  1987    1
#  1946    1
#  1944    1
#  1943    1
#  1954    1
#  1984    1
#  2020    1
#  2019    1
#  2009    1
#  2008    1
#  1932    1
# Name: Established, dtype: int64

# %%
data.Established.head()
# Out:
# 0    1999
# 1    2002
# 2      -1
# 3    1988
# 4    2002
# Name: Established, dtype: int64

# %%
#Replacing -1s in the Established column with False
data.Established=data.Established.replace({-1:False})
data.Established=data.Established.replace({False:'Unknown'})

# %%
data.Established
# Out:
# 0        1999
# 1        2002
# 2     Unknown
# 3        1988
# 4        2002
# 5        1999
# 6     Unknown
# 7     Unknown
# 8     Unknown
# 9     Unknown
# 10       2008
# 11       2009
# 12       1999
# 13       2019
# 14       2020
# 15       1999
# 16       1984
# 17       1943
# 18       1954
# 19       1955
# 20       1944
# 21       1946
# 22       1988
# 23       1999
# 24       1987
# 25       1980
# 26       1934
# 27       1935
# 28       1932
# Name: Established, dtype: object

# %%
data.columns
# Out:
# Index(['Age', 'Salary', 'Location', 'Established', 'Easy Apply',
#        'Rating Scaled'],
#       dtype='object')

# %% [markdown]
# ###Easy apply column

# %%
data['Easy Apply'].head()
# Out:
# 0    TRUE
# 1    TRUE
# 2      -1
# 3      -1
# 4      -1
# Name: Easy Apply, dtype: object

# %%
data['Easy Apply'].value_counts()
# Out:
# TRUE    15
# -1      14
# Name: Easy Apply, dtype: int64

# %%
data['Easy Apply']=data['Easy Apply'].replace({'-1':'FALSE'})

# %%
data['Easy Apply']
# Out:
# 0      TRUE
# 1      TRUE
# 2     FALSE
# 3     FALSE
# 4     FALSE
# 5      TRUE
# 6     FALSE
# 7     FALSE
# 8     FALSE
# 9      TRUE
# 10     TRUE
# 11    FALSE
# 12    FALSE
# 13     TRUE
# 14     TRUE
# 15    FALSE
# 16    FALSE
# 17     TRUE
# 18     TRUE
# 19     TRUE
# 20     TRUE
# 21    FALSE
# 22     TRUE
# 23     TRUE
# 24    FALSE
# 25     TRUE
# 26     TRUE
# 27    FALSE
# 28    FALSE
# Name: Easy Apply, dtype: object

# %%
data['Easy Apply'].isnull().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# Age              0
# Salary           0
# Location         0
# Established      0
# Easy Apply       0
# Rating Scaled    0
# dtype: int64

# %%
data.head()
# Out:
#     Age         Salary   Location Established Easy Apply  Rating Scaled
# 0  44.0   44000- 99000      India        1999       TRUE       0.727273
# 1  66.0   55000- 66000   New York        2002       TRUE       0.511364
# 2  39.0   77000- 89000   New York     Unknown      FALSE       0.000000
# 3  64.0   44000- 99000      India        1988      FALSE       0.613636
# 4  25.0   44000- 99000  Australia        2002      FALSE       0.840909
